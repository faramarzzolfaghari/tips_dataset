# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 12        15.42  1.57    Male     No  Sun  Dinner     2
# 63        18.29  3.76    Male    Yes  Sat  Dinner     4
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3
# 30         9.55  1.45    Male     No  Sat  Dinner     2
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2

# %%
df.groupby('day').count()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24076\1311733119.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('day').count()
#       total_bill  tip  sex  smoker  time  size
# day
# Thur          62   62   62      62    62    62
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76

# %%
df2 = df.groupby('day')[['tip', 'total_bill', 'size']].sum()
df2.drop('size', inplace=True, axis=1)
df2['percent'] = df2['tip']/df2['total_bill']*100
df2
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24076\4103021293.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2 = df.groupby('day')[['tip', 'total_bill', 'size']].sum()
#          tip  total_bill    percent
# day
# Thur  171.83     1096.33  15.673201
# Fri    51.96      325.88  15.944519
# Sat   260.40     1778.40  14.642375
# Sun   247.39     1627.16  15.203791

# %%
df.replace({'sex':{'Male': 0, 'Female': 1}, 'smoker': {'Yes': 1, 'No': 0}}, inplace=True)
df
# Out:
#      total_bill   tip sex smoker   day    time  size
# 0         16.99  1.01   1      0   Sun  Dinner     2
# 1         10.34  1.66   0      0   Sun  Dinner     3
# 2         21.01  3.50   0      0   Sun  Dinner     3
# 3         23.68  3.31   0      0   Sun  Dinner     2
# 4         24.59  3.61   1      0   Sun  Dinner     4
# ..          ...   ...  ..    ...   ...     ...   ...
# 239       29.03  5.92   0      0   Sat  Dinner     3
# 240       27.18  2.00   1      1   Sat  Dinner     2
# 241       22.67  2.00   0      1   Sat  Dinner     2
# 242       17.82  1.75   0      0   Sat  Dinner     2
# 243       18.78  3.00   1      0  Thur  Dinner     2
#
# [244 rows x 7 columns]
